# %%
s1={1,2,3,4}
s2={1,2,'a','b'}

# %%
s1
# Out:
# {1, 2, 3, 4}

# %%
s2
# Out:
# {1, 2, 'a', 'b'}

# %%
s3=frozenset(s1)

# %%
s3   # s3 frozenset
# Out:
# frozenset({1, 2, 3, 4})

# %%
from IPython.display import Image

# %%
Image('Day_photo.PNG')

# %%
s1={1,2,3,4}
s2={1,2,'a','b'}

# %%
s1
# Out:
# {1, 2, 3, 4}

# %%
s2
# Out:
# {1, 2, 'a', 'b'}

# %% [markdown]
# # Add()

# %%
s1.add(8)   # add() element add kora

# %%
s1
# Out:
# {1, 2, 3, 4, 8}

# %% [markdown]
# # Clear()

# %%
s1
# Out:
# {1, 2, 3, 4, 8}

# %%
s3=s1

# %%
s3
# Out:
# {1, 2, 3, 4, 8}

# %%
s4=s1.copy()

# %%
s4
# Out:
# {1, 2, 3, 4, 8}

# %%
s1.add(10) # s1 10 add korsi

# %%
s1
# Out:
# {1, 2, 3, 4, 8, 10}

# %%
s3
# Out:
# {1, 2, 3, 4, 8, 10}

# %%
s4
# Out:
# {1, 2, 3, 4, 8}

# %% [markdown]
# # Difference()

# %%
s1
# Out:
# {1, 2, 3, 4, 8, 10}

# %%
s2
# Out:
# {1, 2, 'a', 'b'}

# %%
s1.difference(s2)
# Out:
# {3, 4, 8, 10}

# %%
s2.difference(s1)
# Out:
# {'a', 'b'}

# %% [markdown]
# # difference_update

# %% [markdown]
# difference_update hosse difference age je value silo seta bad diye difference pore je value aslo seta hobe

# %%
s1
# Out:
# {1, 2, 3, 4, 8, 10}

# %%
s1.difference_update(s2)

# %%
s1
# Out:
# {3, 4, 8, 10}

# %% [markdown]
# # issubset()

# %%
s5={1,2,3}

# %%
s6={4,6,7}

# %%
s5.issubset(s6)
# Out:
# False

# %%
{1}.issubset(s5)
# Out:
# True

# %%
{3}.issubset(s5)
# Out:
# True

# %%
{4}.issubset(s5)
# Out:
# False

# %% [markdown]
# # issuperset

# %%
s5
# Out:
# {1, 2, 3}

# %%
s5.issuperset({2})
# Out:
# True

# %%
s5.issuperset({3})
# Out:
# True

# %%
s5.issuperset({4})
# Out:
# False

# %% [markdown]
# # symmetric_difference

# %%
s7={1,2,3,4}
s8={1,2,7,8}

# %%
s7
# Out:
# {1, 2, 3, 4}

# %%
s8
# Out:
# {1, 2, 7, 8}

# %%
s7.symmetric_difference(s8)
# Out:
# {3, 4, 7, 8}

# %%
s7.symmetric_difference_update(s8)

# %%
s7
# Out:
# {3, 4, 7, 8}
