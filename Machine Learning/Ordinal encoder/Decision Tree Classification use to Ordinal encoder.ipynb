# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv('shop data.csv')

# %%
df
# Out:
#       age  income  gender m_status buys
# 0     <25    high    male   single   no
# 1     <25    high    male  married   no
# 2   25-35    high    male   single  yes
# 3     >35  medium    male   single  yes
# 4     >35     low  female   single  yes
# 5     >35     low  female   single   no
# 6   25-35     low  female  married  yes
# 7     <25  medium    male  married   no
# 8     <25     low  female   single  yes
# 9     >35  medium  female  married  yes
# 10    <25  medium  female   single  yes
# 11  25-35  medium    male  married  yes
# 12  25-35    high  female   single  yes
# 13    >35  medium    male  married   no
# 14    <25    high    male   single   no

# %%
df['income'].unique()
# Out:
# array(['high', 'medium', 'low'], dtype=object)

# %%
income_order=['low','medium','high']  # 0=low, 1=medium,2=high

# %% [markdown]
# ordinalEncoder use korte hoile ata import korte hoi

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
enco=OrdinalEncoder(categories=[income_order])  # Object

# %%
enco.fit(df[['income']])
# Out:
# OrdinalEncoder(categories=[['low', 'medium', 'high']])

# %%
final=pd.DataFrame(enco.transform(df[['income']]))

# %%
df
# Out:
#       age  income  gender m_status buys
# 0     <25    high    male   single   no
# 1     <25    high    male  married   no
# 2   25-35    high    male   single  yes
# 3     >35  medium    male   single  yes
# 4     >35     low  female   single  yes
# 5     >35     low  female   single   no
# 6   25-35     low  female  married  yes
# 7     <25  medium    male  married   no
# 8     <25     low  female   single  yes
# 9     >35  medium  female  married  yes
# 10    <25  medium  female   single  yes
# 11  25-35  medium    male  married  yes
# 12  25-35    high  female   single  yes
# 13    >35  medium    male  married   no
# 14    <25    high    male   single   no

# %%
df['income']=final  # income value Replace

# %%
df
# Out:
#       age  income  gender m_status buys
# 0     <25     2.0    male   single   no
# 1     <25     2.0    male  married   no
# 2   25-35     2.0    male   single  yes
# 3     >35     1.0    male   single  yes
# 4     >35     0.0  female   single  yes
# 5     >35     0.0  female   single   no
# 6   25-35     0.0  female  married  yes
# 7     <25     1.0    male  married   no
# 8     <25     0.0  female   single  yes
# 9     >35     1.0  female  married  yes
# 10    <25     1.0  female   single  yes
# 11  25-35     1.0    male  married  yes
# 12  25-35     2.0  female   single  yes
# 13    >35     1.0    male  married   no
# 14    <25     2.0    male   single   no

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df['age']=le.fit_transform(df['age'])

# %%
df
# Out:
#     age  income  gender m_status buys
# 0     1     2.0    male   single   no
# 1     1     2.0    male  married   no
# 2     0     2.0    male   single  yes
# 3     2     1.0    male   single  yes
# 4     2     0.0  female   single  yes
# 5     2     0.0  female   single   no
# 6     0     0.0  female  married  yes
# 7     1     1.0    male  married   no
# 8     1     0.0  female   single  yes
# 9     2     1.0  female  married  yes
# 10    1     1.0  female   single  yes
# 11    0     1.0    male  married  yes
# 12    0     2.0  female   single  yes
# 13    2     1.0    male  married   no
# 14    1     2.0    male   single   no

# %%
df['gender']=le.fit_transform(df['gender'])

# %%
df
# Out:
#     age  income  gender m_status buys
# 0     1     2.0       1   single   no
# 1     1     2.0       1  married   no
# 2     0     2.0       1   single  yes
# 3     2     1.0       1   single  yes
# 4     2     0.0       0   single  yes
# 5     2     0.0       0   single   no
# 6     0     0.0       0  married  yes
# 7     1     1.0       1  married   no
# 8     1     0.0       0   single  yes
# 9     2     1.0       0  married  yes
# 10    1     1.0       0   single  yes
# 11    0     1.0       1  married  yes
# 12    0     2.0       0   single  yes
# 13    2     1.0       1  married   no
# 14    1     2.0       1   single   no

# %%
df['m_status']=le.fit_transform(df['m_status'])

# %%
df
# Out:
#     age  income  gender  m_status buys
# 0     1     2.0       1         1   no
# 1     1     2.0       1         0   no
# 2     0     2.0       1         1  yes
# 3     2     1.0       1         1  yes
# 4     2     0.0       0         1  yes
# 5     2     0.0       0         1   no
# 6     0     0.0       0         0  yes
# 7     1     1.0       1         0   no
# 8     1     0.0       0         1  yes
# 9     2     1.0       0         0  yes
# 10    1     1.0       0         1  yes
# 11    0     1.0       1         0  yes
# 12    0     2.0       0         1  yes
# 13    2     1.0       1         0   no
# 14    1     2.0       1         1   no

# %% [markdown]
# # x and y separet

# %%
x=df.iloc[:,:-1]

# %%
x
# Out:
#     age  income  gender  m_status
# 0     1     2.0       1         1
# 1     1     2.0       1         0
# 2     0     2.0       1         1
# 3     2     1.0       1         1
# 4     2     0.0       0         1
# 5     2     0.0       0         1
# 6     0     0.0       0         0
# 7     1     1.0       1         0
# 8     1     0.0       0         1
# 9     2     1.0       0         0
# 10    1     1.0       0         1
# 11    0     1.0       1         0
# 12    0     2.0       0         1
# 13    2     1.0       1         0
# 14    1     2.0       1         1

# %%
y=df.iloc[:,4]

# %%
y
# Out:
# 0      no
# 1      no
# 2     yes
# 3     yes
# 4     yes
# 5      no
# 6     yes
# 7      no
# 8     yes
# 9     yes
# 10    yes
# 11    yes
# 12    yes
# 13     no
# 14     no
# Name: buys, dtype: object

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc=DecisionTreeClassifier()

# %%
dtc_=dtc.fit(x,y)

# %%
prediction=dtc_.predict([[1,2,1,1]])

# %%
prediction
# Out:
# array(['no'], dtype=object)

# %%
prediction=dtc_.predict([[2,1,1,1]])

# %%
prediction
# Out:
# array(['yes'], dtype=object)
